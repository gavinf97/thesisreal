# %%
#working with a large gbk file
from Bio import SeqIO
#gbk_file = open('/thesis/python_r/ERR1293545.contigs.gbk', 'r')
#thesis/python_r/44gcluster_work_files/

#!!!Rename in & out files!!!
# Set input file, output file to write to
gbk_file = "/home/gavin/thesis/python_r/1final_data/8mega_work_files/crc_gbks_of_mega_contigs/unified_crc_gbk/crc_unified_8.gbk"
tsv_file = "/home/gavin/thesis/python_r/1final_data/8mega_work_files/crc_unified_8.output.tsv"      # can be .txt, .csv etc.. 
cluster_out = open(tsv_file, "w")

# Extract Cluster info, write to file
for seq_record in SeqIO.parse(gbk_file, "genbank"):
    #print(seq_record)
    for seq_feat in seq_record.features:
        #print(seq_feat.qualifiers)
        if seq_feat.type == "cand_cluster":
            print(seq_feat.qualifiers["product"][0])
                #cluster_number = seq_feat.qualifiers["note"][0].replace(" ","_").replace(":","")
            cluster_type = seq_feat.qualifiers["product"][0]
            cluster_out.write("Cluster Type\t"+cluster_type+"\n")
            #cluster_out.write(cluster_type+"\n")
# Out:
# sactipeptide
# NRPS
# NRPS
# NRPS
# NRPS-like
# NRPS
# bacteriocin
# arylpolyene
# NRPS
# bacteriocin
# betalactone
# sactipeptide
# ladderane
# arylpolyene
# sactipeptide
# sactipeptide
# arylpolyene
# sactipeptide
# sactipeptide
# lassopeptide
# sactipeptide
# NRPS
# NRPS
# NRPS
# bacteriocin
# lanthipeptide
# ranthipeptide
# cyclic-lactone-autoinducer
# cyclic-lactone-autoinducer
# arylpolyene
# RRE-containing
# NRPS
# lanthipeptide-class-ii
# cyclic-lactone-autoinducer
# ranthipeptide
# arylpolyene
# cyclic-lactone-autoinducer
# cyclic-lactone-autoinducer
# NRPS
# cyclic-lactone-autoinducer
# RRE-containing
# arylpolyene
# cyclic-lactone-autoinducer
# cyclic-lactone-autoinducer
# RiPP-like
# cyclic-lactone-autoinducer
# cyclic-lactone-autoinducer
# RRE-containing
# ranthipeptide
# lanthipeptide-class-ii
# NRPS
# RRE-containing
# cyclic-lactone-autoinducer
# ranthipeptide
# lanthipeptide-class-ii
# RRE-containing
# RRE-containing
# cyclic-lactone-autoinducer
# RRE-containing
# ...

# %%
#working with a large gbk file
from Bio import SeqIO
#gbk_file = open('/thesis/python_r/ERR1293545.contigs.gbk', 'r')
#thesis/python_r/44gcluster_work_files/
#

# Set input file, output file to write to
gbk_file = "/home/gavin/thesis/python_r/ERR1293525.contigs.gbk"
tsv_file = "/home/gavin/thesis/python_r/single_check.tsv"      # can be .txt, .csv etc.. 
cluster_out = open(tsv_file, "w")

# Extract Cluster info, write to file
for seq_record in SeqIO.parse(gbk_file, "genbank"):
    #print(seq_record)
    for seq_feat in seq_record.features:
        #print(seq_feat.qualifiers)
        if seq_feat.type == "cand_cluster":
            print(seq_feat.qualifiers["product"][0])
                #cluster_number = seq_feat.qualifiers["note"][0].replace(" ","_").replace(":","")
            cluster_type = seq_feat.qualifiers["product"][0]
            cluster_out.write("Cluster Type\t"+cluster_type+"\n")
# Out:
# arylpolyene
# cyclic-lactone-autoinducer
# cyclic-lactone-autoinducer
# resorcinol
# ranthipeptide
# RRE-containing
# cyclic-lactone-autoinducer
# RRE-containing
# arylpolyene
# RiPP-like
# cyclic-lactone-autoinducer
# RRE-containing
# RiPP-like
# cyclic-lactone-autoinducer
# cyclic-lactone-autoinducer
# ranthipeptide
# cyclic-lactone-autoinducer
# cyclic-lactone-autoinducer
# ranthipeptide
# cyclic-lactone-autoinducer
# ranthipeptide
# terpene
# cyclic-lactone-autoinducer
# ranthipeptide
# cyclic-lactone-autoinducer
# cyclic-lactone-autoinducer
# cyclic-lactone-autoinducer
# cyclic-lactone-autoinducer
# RRE-containing
# RRE-containing

# %%
x = SeqIO.read(gbk_file, "genbank")
print(x)
x.count("NRPS")

#with open('all10_crc_merged.gbk') as gbk_file:
    #bgcs_list = bgc.readlines() #all in one list, each line an item string
 #   gbk_string = gbk_file.read() #all in one string
#print(gbk_file)
#gbk_file.count("NRPS")

# %%
gbk_file = open('/thesis/python_r/ERR1293545.contigs.gbk', 'r')

# %%
import os
from Bio import SeqIO

x = SeqIO.read("ERR1293545.contigs.gbk", 'gb')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-c4c8912afa30> in <module>
#       2 from Bio import SeqIO
#       3
# ----> 4 x = SeqIO.read("ERR1293545.contigs.gbk", 'gb')
#
# ~/anaconda3/lib/python3.8/site-packages/Bio/SeqIO/__init__.py in read(handle, format, alphabet)
#     657     try:
#     658         next(iterator)
# --> 659         raise ValueError("More than one record found in handle")
#     660     except StopIteration:
#     661         pass
#
# ValueError: More than one record found in handle

# %%
cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory
print("Files in %r: %s" % (cwd, files))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2bde94dcdd98> in <module>
# ----> 1 cwd = os.getcwd()  # Get the current working directory (cwd)
#       2 files = os.listdir(cwd)  # Get all the files in that directory
#       3 print("Files in %r: %s" % (cwd, files))
#
# NameError: name 'os' is not defined

# %%
#Parse out fasta data for use
